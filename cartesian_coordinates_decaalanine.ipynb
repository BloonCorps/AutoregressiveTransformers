# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.distributions as dist
import torch.optim as optim

from torch.utils.data import DataLoader
import sys
import os

#Custom
import utilities
torch.max_split_size_mb = 6000

# %%
MMCD_path = "./"
sys.path.append(MMCD_path)
from mmcd import MMCDataset

name = 'decaalanine'
data_path = os.path.join(MMCD_path, "data")

dataset_train = MMCDataset(root = data_path,
                           molecule_name = name,
                           train = True,
                           coordinate_type = 'xyz',
                           lazy_load = False)

whole_loader = DataLoader(dataset_train,
                          num_workers = 1,
                          batch_size = 160000, 
                          shuffle = True)

train_loader = DataLoader(dataset_train,
                          num_workers = 1,
                          batch_size = 256, #256 is the default batch size
                          shuffle = True)

# %%
for batch_idx, xyz in enumerate(whole_loader):
    break

# %%
xyz = xyz.cpu().numpy()

# %%
for iter in range(0, 102, 1):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    fig.suptitle('Coordinate: ' + str(iter))
    ax1.hist(xyz[:5000, iter, 0], bins = 200)
    ax2.hist(xyz[:5000, iter, 1], bins = 200)
    ax3.hist(xyz[:5000, iter, 2], bins = 200)
    plt.show()
