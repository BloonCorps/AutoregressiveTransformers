# %%
"""
Train a baseline autoregressive model that uses a causal LM approach to generating
series of angles
"""
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.append('/bin/')
sys.path.append('bin')
sys.path.append('bin/')
sys.path.append('/bin')

import os
from pathlib import Path
import json
import argparse
from datetime import datetime
import logging
import multiprocessing
from typing import *

import numpy as np
import torch
from torch.utils.data import DataLoader
import pytorch_lightning as pl
from pytorch_lightning.strategies.ddp import DDPStrategy

from transformers import BertConfig

from foldingdiff import datasets, modelling, losses, plotting, utils
from foldingdiff import custom_metrics as cm

from train import ANGLES_DEFINITIONS, build_callbacks, record_args_and_metadata

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.distributions as dist
import torch.optim as optim
from torch import nn, einsum
from torch.utils.data import DataLoader

#my codes
import transformer
import utilities

# %%
def get_train_valid_test_sets(
    angles_definitions: ANGLES_DEFINITIONS = "canonical-full-angles",
    max_seq_len: int = 512,
    min_seq_len: int = 0,
    seq_trim_strategy: datasets.TRIM_STRATEGIES = "leftalign",
) -> Tuple[
    datasets.AutoregressiveCausalDataset,
    datasets.AutoregressiveCausalDataset,
    datasets.AutoregressiveCausalDataset,
]:
    """
    Get the train/valid/test splits using the autoregressive wrapper on the datsets
    """

    clean_dset_class = {
        "canonical": datasets.CathCanonicalAnglesDataset,
        "canonical-full-angles": datasets.CathCanonicalAnglesOnlyDataset,
        "canonical-minimal-angles": datasets.CathCanonicalMinimalAnglesDataset,
        "cart-coords": datasets.CathCanonicalCoordsDataset,
    }[angles_definitions]
    logging.info(f"Clean dataset class: {clean_dset_class}")

    splits = ["train", "validation", "test"]
    logging.info(f"Creating data splits: {splits}")
    clean_dsets = [
        clean_dset_class(
            split=s,
            pad=max_seq_len,
            min_length=min_seq_len,
            trim_strategy=seq_trim_strategy,
            zero_center=False if angles_definitions == "cart-coords" else True,
        )
        for s in splits
    ]

    # Set the training set mean to the validation set mean
    if len(clean_dsets) > 1 and clean_dsets[0].means is not None:
        logging.info(f"Updating valid/test mean offset to {clean_dsets[0].means}")
        for i in range(1, len(clean_dsets)):
            clean_dsets[i].means = clean_dsets[0].means

    causal_dsets = [
        datasets.AutoregressiveCausalDataset(
            d, dset_key="coords" if angles_definitions == "cart-coords" else "angles"
        )
        for d in clean_dsets
    ]
    for dsname, ds in zip(splits, causal_dsets):
        logging.info(f"{dsname}: {ds}")
    return causal_dsets

def return_dataset(
    ### Well, really only returns a dataset. 
    results_dir: str = "./results",
    angles_definitions: ANGLES_DEFINITIONS = "canonical-full-angles",
    max_seq_len: int = 128,
    min_seq_len: int = 40,
    trim_strategy: datasets.TRIM_STRATEGIES = "randomcrop",
    # Related to model architecture
    seq_len_encoding: modelling.TIME_ENCODING = "gaussian_fourier",  # Embeds the total sequence length
    num_hidden_layers: int = 12,  # Default 12
    hidden_size: int = 384,  # Default 768
    intermediate_size: int = 768,  # Default 3072
    num_heads: int = 12,  # Default 12
    position_embedding_type: Literal[
        "absolute", "relative_key_query", "relative_key"
    ] = "absolute",  # Default absolute
    dropout_p: float = 0.1,
    decoder: modelling.DECODER_HEAD = "mlp",
    # Related to training strategy
    gradient_clip: float = 1.0,
    batch_size: int = 256,
    lr: float = 5e-5,
    l2_norm: float = 0.01,
    loss: modelling.LOSS_KEYS = "smooth_l1",
    min_epochs: Optional[int] = None,
    max_epochs: int = 10000,  # 10000, set to 100 for debug
    early_stop_patience: int = 0,  # Set to 0 to disable early stopping
    lr_scheduler: modelling.LR_SCHEDULE = "LinearWarmup",  # Try LinearWarmup?
    use_swa: bool = False,
):
    """
    Train the model
    """
    func_args = locals()

    ft_key = "coords" if angles_definitions == "cart-coords" else "angles"
    dsets = get_train_valid_test_sets(
        angles_definitions=angles_definitions,
        max_seq_len=max_seq_len,
        min_seq_len=min_seq_len,
        seq_trim_strategy=trim_strategy,
    )
    assert len(dsets) == 3

    # Calculate effective batch size
    # https://pytorch-lightning.readthedocs.io/en/1.4.0/advanced/multi_gpu.html#batch-size
    # Under DDP, effective batch size is batch_size * num_gpus * num_nodes
    effective_batch_size = batch_size
    if torch.cuda.is_available():
        effective_batch_size = int(batch_size / torch.cuda.device_count())
    pl.utilities.rank_zero_info(
        f"Given batch size: {batch_size} --> effective batch size with {torch.cuda.device_count()} GPUs: {effective_batch_size}"
    )

    # Create data loaders
    train_dataloader, valid_dataloader, test_dataloader = [
        DataLoader(
            dataset=ds,
            batch_size=effective_batch_size,
            shuffle=i == 0,  # Shuffle only train loader
            num_workers=multiprocessing.cpu_count(),
            pin_memory=True,
        )
        for i, ds in enumerate(dsets)
    ]

    logging.info(f"Using loss function: {loss}")
    
    return train_dataloader, valid_dataloader, test_dataloader

# %%
train_dataloader, valid_dataloader, test_dataloader = return_dataset()
# Out:
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/util.py:47: RuntimeWarning: invalid value encountered in divide
#   v /= factor[..., np.newaxis]
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1969 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1018 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 664 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 992 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1148 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 983 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1667 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1387 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 820 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1513 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1566 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2514 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1220 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 958 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 677 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2732 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 651 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 959 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1199 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1647 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1277 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1103 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 888 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1314 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 448 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1554 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1171 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2104 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1097 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1569 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 3440 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2360 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 787 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2173 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1466 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 233 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1101 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 3218 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 796 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1640 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2527 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2072 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1592 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 3101 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1645 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 553 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1700 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1253 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 690 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1452 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1037 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 4064 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 946 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# ...
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1023 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1411 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 685 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 840 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 4379 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 495 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2034 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1266 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 4165 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 626 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1173 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2747 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2537 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 887 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 321 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1081 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1312 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2199 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 600 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1467 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 756 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 931 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2029 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 419 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 450 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 884 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1595 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 881 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1603 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 238 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1287 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 901 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 734 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 402 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 784 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1589 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 707 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 3910 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 795 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1654 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 783 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 793 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2830 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1546 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1064 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1336 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2391 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1788 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1106 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 599 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 665 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1133 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2750 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1112 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 571 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 807 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1136 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 855 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1052 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1172 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1069 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 4546 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 800 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1029 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 2024 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 3954 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 412 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 3157 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 421 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# /home/gridsan/jzheng/.conda/envs/UROP/lib/python3.10/site-packages/biotite/structure/io/pdb/file.py:423: UserWarning: 1005 elements were guessed from atom_name.
#   warn("{} elements were guessed from atom_name.".format(rep_num))
# Given batch size: 256 --> effective batch size with 1 GPUs: 256

# %%
GLOBAL_NUM_BINS = 600
GLOBAL_BATCH_SIZE = 157

# %%
device = torch.device("cuda:0")
torch.cuda.empty_cache()

model = transformer.UnconditionalTransformer(seq_len=128, hidden_size=512, num_bins=GLOBAL_NUM_BINS, 
                             dropout=0.05, dnlayers=4, batch_size=GLOBAL_BATCH_SIZE, 
                             ffn_hidden_size=256, num_heads=1, qk_depth=128, 
                             v_depth=128, pseudolikelihood=True, device=device).to(device)

# %%
loss_over_time = []
model.train()
optimizer = optim.Adam(model.parameters(), lr=0.0001) 
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max = 10, eta_min=0, last_epoch= -1, verbose=False)

def train_loop(epoch):
    train_loss = 0
    for batch_idx, data_dict in enumerate(train_dataloader):
        
        data = dict_data['angles'].to(device)
        
        target = utilities.custom_bucketize(data, GLOBAL_NUM_BINS).to(device)
        
        optimizer.zero_grad()
        
        softmax_X_pred, attn_mats = model(decoder_input=data, return_attention=True) 
        #softmax_X_pred = model(decoder_input=target)#, return_attention=True) 
        
        loss = model.loss(X=softmax_X_pred, Y=target) + 1e-9*torch.sum(torch.abs(attn_mats))
            
        loss.backward()
        train_loss += loss.item()
        
        #clip grad norm
        torch.nn.utils.clip_grad_value_(model.parameters(), 1)
        
        optimizer.step()
        
        if batch_idx % 50 == 0:#args.log_interval == 0: #by default, args.log_interval = 10
            print('Train Epoch:', epoch, '[{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                batch_idx, #index of the batch we are on 
                len(train_loader), #how many batches are in the data loader
                100. * batch_idx / len(train_loader), #progress percentage
                loss.item() / GLOBAL_BATCH_SIZE#,  #hardcoded batch size
                ))
            loss_over_time.append(loss.item()/len(train_loader) )
            torch.set_printoptions(threshold=10_000)
            
import time
start = time.time()

for epoch in range(0, 20, 1):
    train_loop(epoch)

end = time.time()
elapsed_time = end - start
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [31], in <cell line: 43>()
#      41 start = time.time()
#      43 for epoch in range(0, 20, 1):
# ---> 44     train_loop(epoch)
#      46 end = time.time()
#      47 elapsed_time = end - start
#
# Input In [31], in train_loop(epoch)
#      13 target = utilities.custom_bucketize(data, GLOBAL_NUM_BINS).to(device)
#      15 optimizer.zero_grad()
# ---> 17 softmax_X_pred, attn_mats = model(decoder_input=data, return_attention=True)
#      18 #softmax_X_pred = model(decoder_input=target)#, return_attention=True)
#      20 loss = model.loss(X=softmax_X_pred, Y=target) + 1e-9*torch.sum(torch.abs(attn_mats))
#
# File ~/.conda/envs/UROP/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/MIT/AutoregressiveTransformers/transformer.py:165, in UnconditionalTransformer.forward(self, decoder_input, sampling, parallel_sampling, return_attention)
#     163 #if psuedolikelihood, then no shifting needed
#     164 elif self.pseudolikelihood == True:
# --> 165     decoder_input = self.embeds(decoder_input) * (self.hidden_size ** 0.5)
#     166 else:
#     167     raise NotImplementedError #can only be autoregressive or pseudolikelihood
#
# File ~/.conda/envs/UROP/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/UROP/lib/python3.10/site-packages/torch/nn/modules/sparse.py:158, in Embedding.forward(self, input)
#     157 def forward(self, input: Tensor) -> Tensor:
# --> 158     return F.embedding(
#     159         input, self.weight, self.padding_idx, self.max_norm,
#     160         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/.conda/envs/UROP/lib/python3.10/site-packages/torch/nn/functional.py:2199, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2193     # Note [embedding_renorm set_grad_enabled]
#    2194     # XXX: equivalent to
#    2195     # with torch.no_grad():
#    2196     #   torch.embedding_renorm_
#    2197     # remove once script supports set_grad_enabled
#    2198     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2199 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected tensor for argument #1 'indices' to have one of the following scalar types: Long, Int; but got torch.cuda.FloatTensor instead (while checking arguments for embedding)
