# %% [markdown]
# Load in data from data folder and spit it out in data loader

# %%
import os
import torch
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

from torch.utils.data.dataloader import DataLoader
from foldingdiff import modelling
from foldingdiff import datasets as dsets
import numpy as np

# instance variables 'trim_strategy', 'pad', 'min_length', 'pdbs_src', 'structures', 'cache_dir', 'rng', 'means', 'all_lengths', '_length_rng', 'feature_idx'

clean_dset = dsets.CathCanonicalAnglesOnlyDataset(pad=128, trim_strategy='randomcrop')


print("instance variables in clean_dset", clean_dset.__dict__.keys())
print("all lengths", clean_dset.all_lengths)

max_length = 0 #need to find maximum length for padding purposes
for length in clean_dset.all_lengths:
    if length > max_length:
        max_length = length 

dset_angles = [] #list of matrices, each matrix represents one protein
dset_fnames = [] #list of file names, aligned to dset_angles
for i in range(len(clean_dset.structures)):
    structure = clean_dset.structures[i]
    structure_np = structure["angles"].to_numpy()
    np.nan_to_num(structure_np)
    rows = structure_np.shape[0]
    rows_to_add = max_length - rows
    structure_np_padded = np.pad(structure_np, pad_width=((0,rows_to_add), (0,0)))

    # we need to pad this to have the shape (max_length, 9)
    dset_angles.append(structure_np_padded)
    dset_fnames.append(structure["fname"])

dl = DataLoader(dset_angles, batch_size=32, shuffle=False)
for (batch_idx, data) in enumerate(dl):
    print(data.size())
# Out:
# instance variables in clean_dset dict_keys(['trim_strategy', 'pad', 'min_length', 'pdbs_src', 'fnames', 'structures', 'cache_dir', 'rng', 'means', 'all_lengths', '_length_rng', 'feature_idx'])
# all lengths [135, 192, 241, 157, 65, 230, 146, 197, 85, 63, 123, 139, 248, 173, 244, 101, 104, 157, 154, 130, 346, 79, 81, 307, 101, 85, 176, 123, 302, 383, 95, 201, 62, 116, 101, 113, 81, 121, 141, 126, 206, 73, 345, 226, 75, 154, 119, 99, 112, 150, 115, 97, 93, 210, 118, 78, 173, 69, 91, 52, 119, 171, 74, 86, 101, 138, 127, 113, 168, 141, 221, 307, 219, 155, 67, 125, 87, 216, 391, 144, 142, 216, 52, 88, 256, 102, 179, 205, 164, 488, 291, 103, 87, 74, 100, 85, 173, 135, 288, 126, 87, 196, 241, 126, 138, 165, 100, 520, 112, 175, 106, 139, 449, 106, 113, 147, 54, 128, 259, 98, 168, 41, 176, 80, 188, 65, 146, 205, 141, 48, 103, 193, 44, 152, 271, 208, 189, 201, 165, 221, 125, 108, 176, 141, 174, 145, 148, 129, 47, 121, 81, 193, 131, 123, 84, 105, 96, 97, 268, 142, 269, 94, 280, 480, 155, 80, 119, 174, 156, 127, 89, 115, 194, 146, 93, 156, 126, 79, 147, 145, 271, 146, 108, 76, 89, 230, 303, 111, 89, 88, 100, 101, 161, 140, 249, 74, 125]
# torch.Size([32, 520, 9])
# torch.Size([32, 520, 9])
# torch.Size([32, 520, 9])
# torch.Size([32, 520, 9])
# torch.Size([32, 520, 9])
# torch.Size([32, 520, 9])
# torch.Size([5, 520, 9])

# %%
structure_one = clean_dset.structures[0]

print(structure_one.keys())

print(structure_one['coords'])
# Out:
# dict_keys(['angles', 'coords', 'fname'])
# [[ 7.5550e+00 -3.0420e+00  4.0292e+01]
#  [ 9.3150e+00  2.5600e-01  3.9361e+01]
#  [ 8.0100e+00  3.8300e+00  3.9430e+01]
#  [ 9.0360e+00  4.8810e+00  3.5888e+01]
#  [ 6.3950e+00  2.9440e+00  3.3935e+01]
#  [ 3.7850e+00  3.5820e+00  3.6677e+01]
#  [ 4.3480e+00  7.3710e+00  3.6455e+01]
#  [ 3.6120e+00  7.1230e+00  3.2731e+01]
#  [ 5.2900e-01  4.9350e+00  3.3477e+01]
#  [-9.3300e-01  7.5650e+00  3.5809e+01]
#  [-1.1600e-01  1.0432e+01  3.3452e+01]
#  [-1.8110e+00  8.5870e+00  3.0643e+01]
#  [-4.9200e+00  8.0360e+00  3.2766e+01]
#  [-4.9510e+00  1.1670e+01  3.3968e+01]
#  [-4.7530e+00  1.2968e+01  3.0407e+01]
#  [-7.5150e+00  1.0671e+01  2.9127e+01]
#  [-1.1072e+01  1.1900e+01  2.8571e+01]
#  [-1.2132e+01  8.8870e+00  2.6488e+01]
#  [-1.1349e+01  5.2860e+00  2.7377e+01]
#  [-1.3988e+01 -3.6700e-01  2.7174e+01]
#  [-1.3871e+01 -4.0250e+00  2.6446e+01]
#  [-1.6795e+01 -6.1990e+00  2.7547e+01]
#  [-1.7795e+01 -9.7980e+00  2.7007e+01]
#  [-2.0331e+01 -9.7790e+00  2.4229e+01]
#  [-2.2876e+01 -1.2040e+01  2.2633e+01]
#  [-2.1779e+01 -1.5413e+01  2.1320e+01]
#  [-1.8371e+01 -1.5384e+01  2.2922e+01]
#  [-1.6985e+01 -1.2349e+01  2.1176e+01]
#  [-1.5351e+01 -9.4030e+00  2.2866e+01]
#  [-1.6859e+01 -6.0450e+00  2.2198e+01]
#  [-1.5252e+01 -2.6000e+00  2.2519e+01]
#  [-1.6953e+01  8.0600e-01  2.3026e+01]
#  [-1.5595e+01  4.2870e+00  2.3821e+01]
#  [-1.4008e+01  9.1910e+00  3.2064e+01]
#  [-1.5846e+01  1.1078e+01  3.4819e+01]
#  [-1.3489e+01  1.0583e+01  3.7773e+01]
#  [-1.0796e+01  8.1270e+00  3.8953e+01]
#  [-8.6520e+00  7.3420e+00  4.1933e+01]
#  [-5.1540e+00  6.3390e+00  4.0799e+01]
#  [-5.2740e+00  3.1090e+00  3.8819e+01]
#  [-7.7940e+00  1.3940e+00  4.1138e+01]
#  [-1.1149e+01  3.0920e+00  4.0479e+01]
#  [-1.2643e+01  4.6900e+00  3.7405e+01]
#  [-1.6050e+01  6.2460e+00  3.7008e+01]
#  [-1.7282e+01  6.1640e+00  3.3438e+01]
#  [-2.0326e+01  7.3380e+00  3.1579e+01]
#  [-2.1938e+01  6.1330e+00  2.8441e+01]
#  [-2.5391e+01  6.3240e+00  2.6922e+01]
#  [-2.8134e+01  4.2340e+00  2.8484e+01]
#  [-2.8596e+01  9.1800e-01  2.6650e+01]
#  [-3.0693e+01 -2.0270e+00  2.7786e+01]
#  [-2.8539e+01 -4.4280e+00  2.5768e+01]
#  [-2.7282e+01 -3.4150e+00  3.1056e+01]
#  [-2.8249e+01 -7.0810e+00  3.0398e+01]
#  [-2.4758e+01 -7.9020e+00  2.9179e+01]
#  [-2.3108e+01 -6.4830e+00  3.2253e+01]
#  [-2.5518e+01 -8.2090e+00  3.4663e+01]
#  [-2.4679e+01 -1.1559e+01  3.3063e+01]
#  [-2.0941e+01 -1.0823e+01  3.2937e+01]
#  [-1.9302e+01 -7.7960e+00  3.4576e+01]
#  [-1.5676e+01 -8.7090e+00  3.3701e+01]
#  [-1.4193e+01 -5.9300e+00  3.1539e+01]
#  [-1.1003e+01 -4.1190e+00  3.0596e+01]
#  [-1.0100e+01 -4.7600e-01  3.0017e+01]
#  [-7.5100e+00  5.8800e-01  2.7486e+01]
#  [-5.8110e+00  4.0130e+00  2.7453e+01]
#  [-4.1650e+00  4.9280e+00  2.4199e+01]
#  [-9.3400e-01  6.9170e+00  2.4244e+01]
#  [-1.4080e+00  9.6280e+00  2.1575e+01]
#  [ 2.2840e+00  1.0486e+01  2.1124e+01]
#  [ 3.9570e+00  7.0630e+00  2.0911e+01]
#  [ 3.2160e+00  3.3810e+00  2.0395e+01]
#  [ 2.1920e+00  2.5700e+00  2.3967e+01]
#  [-8.2300e-01  2.0780e+00  2.6161e+01]
#  [-2.2790e+00  8.9400e-01  2.9448e+01]
#  [-6.6060e+00 -2.3780e+00  3.3137e+01]
#  [-8.6330e+00 -5.4500e+00  3.3867e+01]
#  [-1.1367e+01 -5.8690e+00  3.6533e+01]
#  [-1.5129e+01 -5.6660e+00  3.7081e+01]
#  [-1.7728e+01 -2.9410e+00  3.6490e+01]
#  [-2.1008e+01 -1.9510e+00  3.8170e+01]
#  [-2.3770e+01  2.7800e-01  3.6869e+01]
#  [-2.4704e+01  3.0820e+00  3.9288e+01]
#  [-2.8473e+01  3.3040e+00  3.8796e+01]
#  [-2.9012e+01  5.7030e+00  4.1713e+01]
#  [-2.9465e+01  9.4280e+00  4.1223e+01]
#  [-2.7291e+01  1.0214e+01  4.4254e+01]
#  [-2.4190e+01  8.6520e+00  4.2535e+01]
#  [-2.5026e+01  1.0298e+01  3.9204e+01]
#  [-2.5275e+01  1.3650e+01  4.0877e+01]
#  [-2.0142e+01  1.2043e+01  3.9459e+01]
#  [-2.1553e+01  1.4801e+01  3.7249e+01]
#  [-1.8842e+01  1.6997e+01  3.5769e+01]
#  [-1.9048e+01  2.0137e+01  3.3646e+01]
#  [-1.8613e+01  1.8506e+01  3.0213e+01]
#  [-2.1458e+01  1.6080e+01  3.0736e+01]
#  [-2.3835e+01  1.8826e+01  2.9583e+01]
#  [-2.2560e+01  1.8280e+01  2.6015e+01]
#  [-2.3671e+01  1.4650e+01  2.5911e+01]
#  [-2.6584e+01  1.4826e+01  2.8319e+01]
#  [-2.8466e+01  1.8117e+01  2.7704e+01]
#  [-3.1185e+01  1.7426e+01  3.0284e+01]
#  [-2.8539e+01  1.7121e+01  3.3037e+01]
#  [-2.8367e+01  1.4614e+01  3.5877e+01]
#  [-3.1917e+01  1.3454e+01  3.4971e+01]
#  [-3.1186e+01  1.3004e+01  3.1286e+01]
#  [-3.2481e+01  9.4720e+00  3.0625e+01]
#  [-2.9458e+01  8.7190e+00  2.8448e+01]
#  [-2.6969e+01  9.4530e+00  3.1263e+01]
#  [-2.5548e+01  6.2210e+00  3.2730e+01]
#  [-2.2659e+01  6.1590e+00  3.5230e+01]
#  [-2.0533e+01  3.1200e+00  3.6028e+01]
#  [-1.7804e+01  2.2510e+00  3.8480e+01]
#  [-1.4895e+01  1.4800e-01  3.7334e+01]
#  [-1.2627e+01 -1.5500e+00  3.9876e+01]
#  [-9.2180e+00 -2.5760e+00  3.8493e+01]
#  [-7.4550e+00 -5.7020e+00  3.9719e+01]
#  [-4.5070e+00 -5.8370e+00  3.7375e+01]
#  [-2.7200e+00 -3.6940e+00  3.4888e+01]
#  [-6.4700e-01 -4.1760e+00  3.1792e+01]
#  [ 1.6520e+00 -1.4350e+00  3.0458e+01]
#  [ 2.6570e+00 -1.7060e+00  2.6777e+01]
#  [ 5.7470e+00  4.0000e-03  2.5488e+01]
#  [ 8.6660e+00 -8.2000e-01  2.3193e+01]
#  [ 6.7410e+00 -3.8740e+00  2.1816e+01]
#  [ 6.7810e+00 -5.2730e+00  2.5363e+01]
#  [ 4.4880e+00 -5.2770e+00  2.8326e+01]
#  [ 4.7880e+00 -5.2230e+00  3.2071e+01]
#  [ 1.9820e+00 -6.8090e+00  3.4023e+01]
#  [ 1.2100e+00 -5.6980e+00  3.7574e+01]
#  [-1.3720e+00 -6.2820e+00  4.0306e+01]
#  [-3.0380e+00 -3.0020e+00  4.1276e+01]
#  [-3.0440e+00 -3.7710e+00  4.5046e+01]
#  [ 7.3900e-01 -4.3910e+00  4.5048e+01]
#  [ 1.4820e+00 -9.3200e-01  4.3568e+01]]
